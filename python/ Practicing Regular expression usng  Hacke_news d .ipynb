# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.
# Out:
# /kaggle/input/hacker-news-posts/HN_posts_year_to_Sep_26_2016.csv

# %%
import pandas as pd 
hn = pd.read_csv("/kaggle/input/hacker-news-posts/HN_posts_year_to_Sep_26_2016.csv")

# %%
hn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 293119 entries, 0 to 293118
# Data columns (total 7 columns):
# id              293119 non-null int64
# title           293119 non-null object
# url             279256 non-null object
# num_points      293119 non-null int64
# num_comments    293119 non-null int64
# author          293119 non-null object
# created_at      293119 non-null object
# dtypes: int64(3), object(4)
# memory usage: 15.7+ MB

# %%
hn.head()
# Out:
#          id                                              title  \
# 0  12579008  You have two days to comment if you want stem ...
# 1  12579005                         SQLAR  the SQLite Archiver
# 2  12578997  What if we just printed a flatscreen televisio...
# 3  12578989                                  algorithmic music
# 4  12578979  How the Data Vault Enables the Next-Gen Data W...
#
#                                                  url  num_points  \
# 0  http://www.regulations.gov/document?D=FDA-2015...           1
# 1   https://www.sqlite.org/sqlar/doc/trunk/README.md           1
# 2  https://medium.com/vanmoof/our-secrets-out-f21...           1
# 3  http://cacm.acm.org/magazines/2011/7/109891-al...           1
# 4  https://www.talend.com/blog/2016/05/12/talend-...           1
#
#    num_comments        author      created_at
# 0             0       altstar  9/26/2016 3:26
# 1             0      blacksqr  9/26/2016 3:24
# 2             0  pavel_lishin  9/26/2016 3:19
# 3             0  poindontcare  9/26/2016 3:16
# 4             0   markgainor1  9/26/2016 3:14

# %% [markdown]
# Python has a built-in module for regular expressions:
# > The re module, This module contains a number of different functions
# One of the most useful functions from the re module is the re.search() function, which takes two required arguments:
# - The regex pattern
# - The string we want to search that pattern for
# * https://s3.amazonaws.com/dq-content/354/basic_match_1.svg
# - https://s3.amazonaws.com/dq-content/354/basic_match_2.svg
# - https://docs.python.org/3/library/re.html#re.search

# %%
import re

m = re.search("and", "hand")
print(m)
# Out:
# <_sre.SRE_Match object; span=(1, 4), match='and'>

# %%
m = re.search("and", "antidote")
print(m)
# Out:
# None

# %%
string_list = ["Julie's favorite color is Blue.",
               "Keli's favorite color is Green.",
               "Craig's favorite colors are blue and red."]

pattern = "Blue"

for s in string_list:
    if re.search(pattern,s):
        print("Match")
    else:
        print("No Match")
# Out:
# Match
# No Match
# No Match

# %%
blue_mentions = 0
pattern = "Blue"

for s in string_list:
    if re.search(pattern, s):
        blue_mentions += 1

print(blue_mentions)
# Out:
# 1

# %%
blue_mentions = 0
pattern = "[Bb]lue"

for s in string_list:
    if re.search(pattern, s):
        blue_mentions += 1

print(blue_mentions)
# Out:
# 2

# %% [markdown]
# **** Question - How many times Python is mentioned in the title of stories in our Hacker News dataset.

# %%
import re 
titles = hn["title"].tolist()
python_mentions = 0 
pattern = "[Pp]ython"

for s in titles:
    if re.search(pattern,s):
        python_mentions += 1
print(python_mentions)
# Out:
# 2572

# %% [markdown]
# - vectorized methods are often faster and require less code then loops
# *  we can use Series.str.contains() method

# %%
eg_list = ["Julie's favorite color is green.",
           "Keli's favorite color is Blue.",
           "Craig's favorite colors are blue and red."]

eg_series = pd.Series(eg_list)

print(eg_series)
# Out:
# 0             Julie's favorite color is green.
# 1               Keli's favorite color is Blue.
# 2    Craig's favorite colors are blue and red.
# dtype: object

# %%
pattern = "[Bb]lue"
pattern_contained = eg_series.str.contains(pattern)
print(pattern_contained)
# Out:
# 0    False
# 1     True
# 2     True
# dtype: bool

# %%
pattern_count = pattern_contained.sum()
print(pattern_count)
# Out:
# 2

# %% [markdown]
# * method chaining

# %%
pattern_count = eg_series.str.contains(pattern).sum()
print(pattern_count)
# Out:
# 2

# %%
patterns = "[Pp]ython"
titles = hn["title"]
python_mentions = titles.str.contains(patterns)
python_mentions.sum()
# Out:
# 2572

# %%
python_mentions.head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: title, dtype: bool

# %% [markdown]
# * we can use the boolean array returned by Series.str.contains() to select just those rows from our series.

# %%
py_titles = titles[python_mentions]
print(py_titles.head())
# Out:
# 109        Solve a wooden puzzle with Python and Jupyter
# 257    A fast PostgreSQL client library for Python: 3...
# 284                                  Asynchronous Python
# 444    Python 4 Kids: Python for Kids: Python 3  Proj...
# 478    Cubr  A Rubiks Cube Solver Written in Python a...
# Name: title, dtype: object

# %%
py_titles = titles[titles.str.contains("[Pp]ython")]
print(py_titles.head())
# Out:
# 109        Solve a wooden puzzle with Python and Jupyter
# 257    A fast PostgreSQL client library for Python: 3...
# 284                                  Asynchronous Python
# 444    Python 4 Kids: Python for Kids: Python 3  Proj...
# 478    Cubr  A Rubiks Cube Solver Written in Python a...
# Name: title, dtype: object

# %%
titles = hn["title"] 
ruby_titles = titles.str.contains("[Rr]uby")
ruby_titles = titles[ruby_titles]
ruby_titles
# Out:
# 1291                        Wrote a simple ps clone in ruby
# 1497       Ruby Poltergeist gem the best way to scrape data
# 1624      A proposal of new concurrency model for Ruby 3...
# 1734      Ruby gem to fetch gocd information as rich mod...
# 1981                    Ruby vs. Python, the Definitive FAQ
#                                 ...
# 291994    Statically typed Ruby  method signatures somet...
# 292008                       Pros and Cons of Ruby on Rails
# 292456                       PostgreSQL for Ruby Developers
# 292501            Ruby Robotic Vacuum Programming Challenge
# 292779          Collection of expectation matchers for Ruby
# Name: title, Length: 920, dtype: object

# %% [markdown]
# * https://s3.amazonaws.com/dq-content/354/quantifier_example.svg
# - {} use of brackets using quantifier
# - if we wanted to write a pattern that matches the numbers in text from 1000 to 2999 we can represent them [0-2][0-9]{3}
# - As an example, we might want to match both e-mail and email , - 0 or  1 time
# - https://s3.amazonaws.com/dq-content/354/quantifiers_numeric.svg
# - https://s3.amazonaws.com/dq-content/354/quantifiers_other.svg

# %% [markdown]
# ** Question2 -find how many titles in our dataset mention email or e-mail**
# - To do this, we'll need to use ?, the optional quantifier, to specify that the dash character - is optional in our regular expression.

# %%
email_bool = titles.str.contains("e-?mail")
email_count = email_bool.sum()
email_count
email_titles = titles[email_bool]
email_titles
# Out:
# 90        This is what happens when you reply to spam email
# 173                  Correct way to validate email adresses
# 1010      Obama used a pseudonym in emails with Clinton,...
# 1012      The most broken part of your user experience i...
# 1029                 Visualization of Clinton email scandal
#                                 ...
# 291942    U.S., tech industry fight over email privacy h...
# 292071    U.S., tech industry fight over email privacy h...
# 292094    Why you shouldn't use disposable email address...
# 292341    Ex-Tesla engineer could face prison for email ...
# 292778    Show HN: LeadStage emaildomaindb  Flag email a...
# Name: title, Length: 873, dtype: object

# %% [markdown]
# **Finding from Hacker News include a topic tag** e.g [pdf]...[pdf]
# - https://s3.amazonaws.com/dq-content/354/without_escaped_character_syntax_breakdown.svg
# - https://s3.amazonaws.com/dq-content/354/escaped_character_syntax_breakdown.svg to match \[pdf\]
# - To match unknown characters using regular expressions, we use character classes. use backslash  > set notation {}
# >  range notation[1-9]
# ![](http://)https://s3.amazonaws.com/dq-content/354/character_classes_v2_1.svg
#
# - like with quantifiers, there are some other common character classes . \w,\d,\s
# ![](http://)https://s3.amazonaws.com/dq-content/354/character_classes_v2_2.svg
#
# - combined pattern of \w+ (word as well as quantifyers)
# - This will match sequences like pdf, video, Python, and 2018 but won't match a sequence containing a space or punctuation character like PHP-DEV or XKCD Flowchart. If we wanted to match those tags as well, we could use .+

# %% [markdown]
# ** Question how do you count the number of titles that contain a tag.**

# %%
pattern = "\[\w+\]"
tag_titles = titles[titles.str.contains(pattern)]
tag_count = tag_titles.shape[0]
tag_count
# Out:
# 5871

# %%
tag_5 = tag_titles.head()
print(tag_5)
# Out:
# 36     Cuba's DIY Inventions from 30 Years of Isolati...
# 114    A Possible Future of Software Development by  ...
# 153                               FreeBSD Issue #1 [pdf]
# 154       Proprietary versus open instruction sets [pdf]
# 217                      Forever Alone Programming [FAP]
# Name: title, dtype: object

# %%
tag_titles
# Out:
# 36        Cuba's DIY Inventions from 30 Years of Isolati...
# 114       A Possible Future of Software Development by  ...
# 153                                  FreeBSD Issue #1 [pdf]
# 154          Proprietary versus open instruction sets [pdf]
# 217                         Forever Alone Programming [FAP]
#                                 ...
# 292904                      How to Write About Africa [pdf]
# 292944    Interactively Develop a Reactjs Application [v...
# 293044    The Synthesis of Reliable Organisms from Unrel...
# 293075    Saul Bass Pitch Video for Bell System Logo Red...
# 293115    Attention and awareness in stage magic: turnin...
# Name: title, Length: 5871, dtype: object

# %% [markdown]
# - In Python, a backslash followed by certain characters represents an escape sequence — like the \n sequence
# - strongly recommend using raw strings for every regex you write,
# - https://s3.amazonaws.com/dq-content/354/tags_syntax_breakdown_v2.svg
# - We use the Series.str.extract() method to extract the match within our parentheses:

# %%
print('hello\b world')
# Out:
#  world

# %%
print('hello\\b world')
# Out:
# hello\b world

# %%
print(r'hello\b world')
# Out:
# hello\b world

# %%
pattern = r"(\[\w+\])"
tag_5_matches = tag_5.str.extract(pattern)
print(tag_5_matches)
# Out:
#            0
# 36   [video]
# 114  [video]
# 153    [pdf]
# 154    [pdf]
# 217    [FAP]

# %% [markdown]
# * We can move our parentheses inside the brackets to get just the text:

# %%
pattern = r"\[(\w+)\]"
tag_5_matches = tag_5.str.extract(pattern)
print(tag_5_matches)
# Out:
#          0
# 36   video
# 114  video
# 153    pdf
# 154    pdf
# 217    FAP

# %%
tag_5_freq = tag_5_matches[0].value_counts()
print(tag_5_freq)
# Out:
# video    2
# pdf      2
# FAP      1
# Name: 0, dtype: int64

# %% [markdown]
# **Question 4 extract all of the tags from the Hacker News titles and build a frequency table of those tags.**

# %%
#pattern = r"\[\w+\]"
pattern = r"\[(\w+)\]"
tag_freq = titles.str.extract(pattern)[0].value_counts()

tag_freq
# Out:
# pdf            3531
# video          1524
# audio            65
# 2015             23
# Infographic      18
#                ...
# MAP               1
# stable            1
# Dev               1
# DRM               1
# Pirate            1
# Name: 0, Length: 445, dtype: int64

# %% [markdown]
# **create a function that returns the first few matching strings: **
#
# - onlinetool - https://regexr.com
# - https://s3.amazonaws.com/dq-content/354/negative_character_classes.svg

# %%
def first_10_matches(pattern):
    """
    Return the first 10 story titles that match
    the provided regular expression
    """
    all_matches = titles[titles.str.contains(pattern)]
    first_10 = all_matches.head(10)
    return first_10

# %%
# first_10_matches(r"[Jj]ava")

# %% [markdown]
# ** We can using negative character classes.  ** e.g there are a number of matches that contain Java as part of the word JavaScript. We want to exclude these titles from matching so we get an accurate count.
# - https://s3.amazonaws.com/dq-content/354/negative_character_classes.svg

# %% [markdown]
# **Let's use the negative set [^Ss] to exclude instances like JavaScript and Javascript:**

# %%
def first_10_matches(pattern):
    all_matches = titles[titles.str.contains(pattern)]
    first_10 = all_matches.head(10)
    return first_10
pattern = r"[Jj]ava[^Ss]"
java_titles = titles[titles.str.contains(pattern)]
first_10_matches(pattern)
# Out:
# 734     Show HN: New and Painless Couchbase Java SDK W...
# 1244                2016 JavaOne Intel Keynote  32mn Talk
# 1803                  RxJava library for Jersey framework
# 2569    A Demo App of Zhihu Daily Based on MVP and RxJ...
# 2592       Swift versus Java: the bitset performance test
# 2919                            Scala VS Java: fresh view
# 3590    HeapStats: JVMTI agent and JavaFX analyzer for...
# 3904    Red Hat Links Java to Microsoft's Visual Studi...
# 4126    ?Oracle pledges continued support for Java and...
# 4223    How Did We End Up with Java Running Inside of ...
# Name: title, dtype: object

# %% [markdown]
# - side-effect of removing java occurs at the end of sentence
# - A different approach to take in cases like these is to use the word boundary anchor, syntax \b
# - https://s3.amazonaws.com/dq-content/354/word_boundaries.svg

# %%
string = "Sometimes people confuse JavaScript with Java"
pattern_1 = r"Java[^S]"

m1 = re.search(pattern_1, string)
print(m1)
# regular expression returns None
# Out:
# None

# %% [markdown]
# **Let's instead use word boundaries in our regular expression:**

# %%
pattern_2 = r"\bJava\b"
m2 = re.search(pattern_2, string)
print(m2)
# Out:
# <_sre.SRE_Match object; span=(41, 45), match='Java'>

# %%
def first_10_matches(pattern):
    all_matches = titles[titles.str.contains(pattern)]
    first_10 = all_matches.head(10)
    return first_10
pattern = r"\b[Jj]ava\b"
java_titles = titles[titles.str.contains(pattern)]
first_10_matches(pattern)
# Out:
# 734     Show HN: New and Painless Couchbase Java SDK W...
# 2592       Swift versus Java: the bitset performance test
# 2919                            Scala VS Java: fresh view
# 3584                                    Var comes to Java
# 3904    Red Hat Links Java to Microsoft's Visual Studi...
# 4126    ?Oracle pledges continued support for Java and...
# 4223    How Did We End Up with Java Running Inside of ...
# 4315    Java Language Support for Visual Studio Code H...
# 4512    How to find and fix memory leaks in your Java ...
# 4535       A Beginners Guide to Java Internationalization
# Name: title, dtype: object

# %% [markdown]
# **Other than the word boundary anchor, the other two most common anchors are the beginning anchor and the end anchor, which represent the start and the end of the string**
# - https://s3.amazonaws.com/dq-content/354/positional_anchors.svg .. ^ [

# %%
test_cases = pd.Series([
    "Red Nose Day is a well-known fundraising event",
    "My favorite color is Red",
    "My Red Car was purchased three years ago"
])
print(test_cases)
# Out:
# 0    Red Nose Day is a well-known fundraising event
# 1                          My favorite color is Red
# 2          My Red Car was purchased three years ago
# dtype: object

# %% [markdown]
# **Start of the string**

# %%
test_cases.str.contains(r"^Red")
# Out:
# 0     True
# 1    False
# 2    False
# dtype: bool

# %% [markdown]
# **end of the string **

# %%
test_cases.str.contains(r"Red$")
# Out:
# 0    False
# 1     True
# 2    False
# dtype: bool

# %% [markdown]
# **Question5 Beginning and end anchors to count how many titles have tags at the start versus the end of the story title in our Hacker News dataset.**[](http://)

# %%
pattern_beginning = r"^\[\w+\]"
beginning_count = titles.str.contains(pattern_beginning).sum()

pattern_ending =  r"\[\w+\]$"
ending_count = titles.str.contains(pattern_ending).sum()
beginning_count
# Out:
# 304

# %% [markdown]
# - many different formatting styles used to represent the word, we can use flags
# - most common and the most useful is the re.IGNORECASE
# - When you use this flag, all uppercase letters will match their lowercase equivalents and vice versa.

# %%
email_tests = pd.Series(['email', 'Email', 'eMail', 'EMAIL'])
email_tests.str.contains(r"email")
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# dtype: bool

# %%
import re
email_tests.str.contains(r"email",flags=re.I)
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# dtype: bool

# %%
import re

email_tests = pd.Series(['email', 'Email', 'e Mail', 'e mail', 'E-mail',
              'e-mail', 'eMail', 'E-Mail', 'EMAIL'])

pattern = r"\be[\-\s]?mails?\b"
email_mentions = titles.str.contains(pattern,flags=re.I).sum()

# %%
email_mentions
# Out:
# 1653

# %% [markdown]
# * Character classes to match certain groups of characters, including sets to match different capitalizations of programming languages.
# * Quantifiers to match different quantities of characters, including matching different variations of "email."
# * Negative character classes for matching anything except certain groups of characters.
# * Word boundaries to match only specific instances of words.
# * Positional anchors to match only at the start and end of strings.
# * The ignorecase flag to make patterns case insensitive.
