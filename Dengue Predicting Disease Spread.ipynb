# %%
import pandas as pd 
from matplotlib import pyplot as plt
import seaborn as sns

# %%
a_test = pd.read_csv("https://s3.amazonaws.com/drivendata/data/44/public/dengue_features_test.csv")
b_train = pd.read_csv("https://s3.amazonaws.com/drivendata/data/44/public/dengue_features_train.csv")

# %%
labels = pd.read_csv("https://s3.amazonaws.com/drivendata/data/44/public/dengue_labels_train.csv")

# %%
a_test.head()
# Out:
#   city  year  weekofyear week_start_date  ndvi_ne   ndvi_nw   ndvi_se  \
# 0   sj  2008          18      2008-04-29  -0.0189 -0.018900  0.102729
# 1   sj  2008          19      2008-05-06  -0.0180 -0.012400  0.082043
# 2   sj  2008          20      2008-05-13  -0.0015       NaN  0.151083
# 3   sj  2008          21      2008-05-20      NaN -0.019867  0.124329
# 4   sj  2008          22      2008-05-27   0.0568  0.039833  0.062267
#
#     ndvi_sw  precipitation_amt_mm  reanalysis_air_temp_k  ...  \
# 0  0.091200                 78.60             298.492857  ...
# 1  0.072314                 12.56             298.475714  ...
# 2  0.091529                  3.66             299.455714  ...
# 3  0.125686                  0.00             299.690000  ...
# 4  0.075914                  0.76             299.780000  ...
#
#    reanalysis_precip_amt_kg_per_m2  reanalysis_relative_humidity_percent  \
# 0                            25.37                             78.781429
# ...

# %%
labels.head()
# Out:
#   city  year  weekofyear  total_cases
# 0   sj  1990          18            4
# 1   sj  1990          19            5
# 2   sj  1990          20            4
# 3   sj  1990          21            3
# 4   sj  1990          22            6

# %%
labels['year'].unique()
# Out:
# array([1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000,
#        2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010])

# %%
a_test.shape
# Out:
# (416, 24)

# %%
a_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 416 entries, 0 to 415
# Data columns (total 24 columns):
# city                                     416 non-null object
# year                                     416 non-null int64
# weekofyear                               416 non-null int64
# week_start_date                          416 non-null object
# ndvi_ne                                  373 non-null float64
# ndvi_nw                                  405 non-null float64
# ndvi_se                                  415 non-null float64
# ndvi_sw                                  415 non-null float64
# precipitation_amt_mm                     414 non-null float64
# reanalysis_air_temp_k                    414 non-null float64
# reanalysis_avg_temp_k                    414 non-null float64
# reanalysis_dew_point_temp_k              414 non-null float64
# reanalysis_max_air_temp_k                414 non-null float64
# ...

# %%
a_test.describe()
# Out:
#               year  weekofyear     ndvi_ne     ndvi_nw     ndvi_se  \
# count   416.000000  416.000000  373.000000  405.000000  415.000000
# mean   2010.766827   26.439904    0.126050    0.126803    0.207702
# std       1.434835   14.978257    0.164353    0.141420    0.079102
# min    2008.000000    1.000000   -0.463400   -0.211800    0.006200
# 25%    2010.000000   13.750000   -0.001500    0.015975    0.148670
# 50%    2011.000000   26.000000    0.110100    0.088700    0.204171
# 75%    2012.000000   39.000000    0.263329    0.242400    0.254871
# max    2013.000000   53.000000    0.500400    0.649000    0.453043
#
#           ndvi_sw  precipitation_amt_mm  reanalysis_air_temp_k  \
# count  415.000000            414.000000             414.000000
# mean     0.201721             38.354324             298.818295
# std      0.092028             35.171126               1.469501
# min     -0.014671              0.000000             294.554286
# ...

# %%
a_test.columns
# Out:
# Index(['city', 'year', 'weekofyear', 'week_start_date', 'ndvi_ne', 'ndvi_nw',
#        'ndvi_se', 'ndvi_sw', 'precipitation_amt_mm', 'reanalysis_air_temp_k',
#        'reanalysis_avg_temp_k', 'reanalysis_dew_point_temp_k',
#        'reanalysis_max_air_temp_k', 'reanalysis_min_air_temp_k',
#        'reanalysis_precip_amt_kg_per_m2',
#        'reanalysis_relative_humidity_percent', 'reanalysis_sat_precip_amt_mm',
#        'reanalysis_specific_humidity_g_per_kg', 'reanalysis_tdtr_k',
#        'station_avg_temp_c', 'station_diur_temp_rng_c', 'station_max_temp_c',
#        'station_min_temp_c', 'station_precip_mm'],
#       dtype='object')

# %%
a_test.isnull().sum()
# Out:
# city                                      0
# year                                      0
# weekofyear                                0
# week_start_date                           0
# ndvi_ne                                  43
# ndvi_nw                                  11
# ndvi_se                                   1
# ndvi_sw                                   1
# precipitation_amt_mm                      2
# reanalysis_air_temp_k                     2
# reanalysis_avg_temp_k                     2
# reanalysis_dew_point_temp_k               2
# reanalysis_max_air_temp_k                 2
# reanalysis_min_air_temp_k                 2
# reanalysis_precip_amt_kg_per_m2           2
# reanalysis_relative_humidity_percent      2
# reanalysis_sat_precip_amt_mm              2
# reanalysis_specific_humidity_g_per_kg     2
# reanalysis_tdtr_k                         2
# station_avg_temp_c                       12
# station_diur_temp_rng_c                  12
# ...

# %%
import missingno as msno
# %matplotlib inline
msno.matrix(a_test)

# %%
msno.bar(a_test.sample(100))

# %%
sns.heatmap(a_test.isnull(), cbar=False)

# %%
 msno.heatmap(a_test)

# %%
msno.dendrogram(a_test)

# %%
b_train.shape
# Out:
# (1456, 24)

# %%
b_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1456 entries, 0 to 1455
# Data columns (total 24 columns):
# city                                     1456 non-null object
# year                                     1456 non-null int64
# weekofyear                               1456 non-null int64
# week_start_date                          1456 non-null object
# ndvi_ne                                  1262 non-null float64
# ndvi_nw                                  1404 non-null float64
# ndvi_se                                  1434 non-null float64
# ndvi_sw                                  1434 non-null float64
# precipitation_amt_mm                     1443 non-null float64
# reanalysis_air_temp_k                    1446 non-null float64
# reanalysis_avg_temp_k                    1446 non-null float64
# reanalysis_dew_point_temp_k              1446 non-null float64
# reanalysis_max_air_temp_k                1446 non-null float64
# ...

# %%
b_train.describe()
# Out:
#               year   weekofyear      ndvi_ne      ndvi_nw      ndvi_se  \
# count  1456.000000  1456.000000  1262.000000  1404.000000  1434.000000
# mean   2001.031593    26.503434     0.142294     0.130553     0.203783
# std       5.408314    15.019437     0.140531     0.119999     0.073860
# min    1990.000000     1.000000    -0.406250    -0.456100    -0.015533
# 25%    1997.000000    13.750000     0.044950     0.049217     0.155087
# 50%    2002.000000    26.500000     0.128817     0.121429     0.196050
# 75%    2005.000000    39.250000     0.248483     0.216600     0.248846
# max    2010.000000    53.000000     0.508357     0.454429     0.538314
#
#            ndvi_sw  precipitation_amt_mm  reanalysis_air_temp_k  \
# count  1434.000000           1443.000000            1446.000000
# mean      0.202305             45.760388             298.701852
# std       0.083903             43.715537               1.362420
# min      -0.063457              0.000000             294.635714
# ...

# %%
b_train.isnull().sum()
# Out:
# city                                       0
# year                                       0
# weekofyear                                 0
# week_start_date                            0
# ndvi_ne                                  194
# ndvi_nw                                   52
# ndvi_se                                   22
# ndvi_sw                                   22
# precipitation_amt_mm                      13
# reanalysis_air_temp_k                     10
# reanalysis_avg_temp_k                     10
# reanalysis_dew_point_temp_k               10
# reanalysis_max_air_temp_k                 10
# reanalysis_min_air_temp_k                 10
# reanalysis_precip_amt_kg_per_m2           10
# reanalysis_relative_humidity_percent      10
# reanalysis_sat_precip_amt_mm              13
# reanalysis_specific_humidity_g_per_kg     10
# reanalysis_tdtr_k                         10
# station_avg_temp_c                        43
# station_diur_temp_rng_c                   43
# ...

# %%
b_train.columns
# Out:
# Index(['city', 'year', 'weekofyear', 'week_start_date', 'ndvi_ne', 'ndvi_nw',
#        'ndvi_se', 'ndvi_sw', 'precipitation_amt_mm', 'reanalysis_air_temp_k',
#        'reanalysis_avg_temp_k', 'reanalysis_dew_point_temp_k',
#        'reanalysis_max_air_temp_k', 'reanalysis_min_air_temp_k',
#        'reanalysis_precip_amt_kg_per_m2',
#        'reanalysis_relative_humidity_percent', 'reanalysis_sat_precip_amt_mm',
#        'reanalysis_specific_humidity_g_per_kg', 'reanalysis_tdtr_k',
#        'station_avg_temp_c', 'station_diur_temp_rng_c', 'station_max_temp_c',
#        'station_min_temp_c', 'station_precip_mm'],
#       dtype='object')

# %%
import missingno as msno
# %matplotlib inline
msno.matrix(b_train)

# %%
msno.bar(b_train.sample(100))

# %%
sns.heatmap(b_train.isnull(), cbar=False)

# %%
msno.dendrogram(b_train)

# %%
labels.isnull().sum()
# Out:
# city           0
# year           0
# weekofyear     0
# total_cases    0
# dtype: int64

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 416 entries, 0 to 415
# Data columns (total 24 columns):
# city                                     416 non-null object
# year                                     416 non-null int64
# weekofyear                               416 non-null int64
# week_start_date                          416 non-null object
# ndvi_ne                                  373 non-null float64
# ndvi_nw                                  405 non-null float64
# ndvi_se                                  415 non-null float64
# ndvi_sw                                  415 non-null float64
# precipitation_amt_mm                     414 non-null float64
# reanalysis_air_temp_k                    414 non-null float64
# reanalysis_avg_temp_k                    414 non-null float64
# reanalysis_dew_point_temp_k              414 non-null float64
# reanalysis_max_air_temp_k                414 non-null float64
# ...

# %%
b.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1456 entries, 0 to 1455
# Data columns (total 24 columns):
# city                                     1456 non-null object
# year                                     1456 non-null int64
# weekofyear                               1456 non-null int64
# week_start_date                          1456 non-null object
# ndvi_ne                                  1262 non-null float64
# ndvi_nw                                  1404 non-null float64
# ndvi_se                                  1434 non-null float64
# ndvi_sw                                  1434 non-null float64
# precipitation_amt_mm                     1443 non-null float64
# reanalysis_air_temp_k                    1446 non-null float64
# reanalysis_avg_temp_k                    1446 non-null float64
# reanalysis_dew_point_temp_k              1446 non-null float64
# reanalysis_max_air_temp_k                1446 non-null float64
# ...

# %%
labels.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1456 entries, 0 to 1455
# Data columns (total 4 columns):
# city           1456 non-null object
# year           1456 non-null int64
# weekofyear     1456 non-null int64
# total_cases    1456 non-null int64
# dtypes: int64(3), object(1)
# memory usage: 45.6+ KB

# %%
 msno.heatmap(b_train)

# %%
b_train.head()
# Out:
#   city  year  weekofyear week_start_date   ndvi_ne   ndvi_nw   ndvi_se  \
# 0   sj  1990          18      1990-04-30  0.122600  0.103725  0.198483
# 1   sj  1990          19      1990-05-07  0.169900  0.142175  0.162357
# 2   sj  1990          20      1990-05-14  0.032250  0.172967  0.157200
# 3   sj  1990          21      1990-05-21  0.128633  0.245067  0.227557
# 4   sj  1990          22      1990-05-28  0.196200  0.262200  0.251200
#
#     ndvi_sw  precipitation_amt_mm  reanalysis_air_temp_k  ...  \
# 0  0.177617                 12.42             297.572857  ...
# 1  0.155486                 22.82             298.211429  ...
# 2  0.170843                 34.54             298.781429  ...
# 3  0.235886                 15.36             298.987143  ...
# 4  0.247340                  7.52             299.518571  ...
#
#    reanalysis_precip_amt_kg_per_m2  reanalysis_relative_humidity_percent  \
# 0                            32.00                             73.365714
# ...

# %%
# https://towardsdatascience.com/working-with-missing-data-in-machine-learning-9c0a430df4ce
# https://www.geeksforgeeks.org/python-working-with-date-and-time-using-pandas/
import datetime 
b_train['week_start'] = pd.to_datetime(b_train['week_start_date'])

# %%
b_train['week_start'].head()
# Out:
# 0   1990-04-30
# 1   1990-05-07
# 2   1990-05-14
# 3   1990-05-21
# 4   1990-05-28
# Name: week_start, dtype: datetime64[ns]

# %%
b_train = b_train.drop('week_start_date', axis= 1)

# %%
b_train.head()
# Out:
#   city  year  weekofyear   ndvi_ne   ndvi_nw   ndvi_se   ndvi_sw  \
# 0   sj  1990          18  0.122600  0.103725  0.198483  0.177617
# 1   sj  1990          19  0.169900  0.142175  0.162357  0.155486
# 2   sj  1990          20  0.032250  0.172967  0.157200  0.170843
# 3   sj  1990          21  0.128633  0.245067  0.227557  0.235886
# 4   sj  1990          22  0.196200  0.262200  0.251200  0.247340
#
#    precipitation_amt_mm  reanalysis_air_temp_k  reanalysis_avg_temp_k  ...  \
# 0                 12.42             297.572857             297.742857  ...
# 1                 22.82             298.211429             298.442857  ...
# 2                 34.54             298.781429             298.878571  ...
# 3                 15.36             298.987143             299.228571  ...
# 4                  7.52             299.518571             299.664286  ...
#
#    reanalysis_relative_humidity_percent  reanalysis_sat_precip_amt_mm  \
# ...

# %%
pwd
# Out:
# '/Users/apple/d'

# %%
#reanme week_start to week_start_date
b_train.rename(columns= {'week_start':'week_start_date'}, inplace = True)

# %%
b_train.head()
# Out:
#   city  year  weekofyear   ndvi_ne   ndvi_nw   ndvi_se   ndvi_sw  \
# 0   sj  1990          18  0.122600  0.103725  0.198483  0.177617
# 1   sj  1990          19  0.169900  0.142175  0.162357  0.155486
# 2   sj  1990          20  0.032250  0.172967  0.157200  0.170843
# 3   sj  1990          21  0.128633  0.245067  0.227557  0.235886
# 4   sj  1990          22  0.196200  0.262200  0.251200  0.247340
#
#    precipitation_amt_mm  reanalysis_air_temp_k  reanalysis_avg_temp_k  ...  \
# 0                 12.42             297.572857             297.742857  ...
# 1                 22.82             298.211429             298.442857  ...
# 2                 34.54             298.781429             298.878571  ...
# 3                 15.36             298.987143             299.228571  ...
# 4                  7.52             299.518571             299.664286  ...
#
#    reanalysis_relative_humidity_percent  reanalysis_sat_precip_amt_mm  \
# ...

# %%
# rearange the columns 
cols = b_train.columns.to_list()
cols = cols[-1:] + cols[:-1]

# %%
b_train = b_train[cols]

# %%
b_train.head()
# Out:
#   week_start_date city  year  weekofyear   ndvi_ne   ndvi_nw   ndvi_se  \
# 0      1990-04-30   sj  1990          18  0.122600  0.103725  0.198483
# 1      1990-05-07   sj  1990          19  0.169900  0.142175  0.162357
# 2      1990-05-14   sj  1990          20  0.032250  0.172967  0.157200
# 3      1990-05-21   sj  1990          21  0.128633  0.245067  0.227557
# 4      1990-05-28   sj  1990          22  0.196200  0.262200  0.251200
#
#     ndvi_sw  precipitation_amt_mm  reanalysis_air_temp_k  ...  \
# 0  0.177617                 12.42             297.572857  ...
# 1  0.155486                 22.82             298.211429  ...
# 2  0.170843                 34.54             298.781429  ...
# 3  0.235886                 15.36             298.987143  ...
# 4  0.247340                  7.52             299.518571  ...
#
#    reanalysis_precip_amt_kg_per_m2  reanalysis_relative_humidity_percent  \
# 0                            32.00                             73.365714
# ...

# %%
b_train['city'].unique()
# Out:
# array(['sj', 'iq'], dtype=object)

# %%
# https://www.geeksforgeeks.org/rename-multiple-files-using-python/
#https://stackoverflow.com/questions/36729059/using-os-listdir-see-if-an-object-is-a-file-or-a-directory

# %%
# sj and iq 
b_sj = b_train.copy()
b_iq = b_train.copy()

# %%
b_sj.drop(b_sj[b_sj['city'] != 'sj'].index, inplace=True)
b_iq.drop(b_iq[b_iq['city'] != 'iq'].index, inplace=True)

# %%
b_sj.head()
# Out:
#   week_start_date city  year  weekofyear   ndvi_ne   ndvi_nw   ndvi_se  \
# 0      1990-04-30   sj  1990          18  0.122600  0.103725  0.198483
# 1      1990-05-07   sj  1990          19  0.169900  0.142175  0.162357
# 2      1990-05-14   sj  1990          20  0.032250  0.172967  0.157200
# 3      1990-05-21   sj  1990          21  0.128633  0.245067  0.227557
# 4      1990-05-28   sj  1990          22  0.196200  0.262200  0.251200
#
#     ndvi_sw  precipitation_amt_mm  reanalysis_air_temp_k  ...  \
# 0  0.177617                 12.42             297.572857  ...
# 1  0.155486                 22.82             298.211429  ...
# 2  0.170843                 34.54             298.781429  ...
# 3  0.235886                 15.36             298.987143  ...
# 4  0.247340                  7.52             299.518571  ...
#
#    reanalysis_precip_amt_kg_per_m2  reanalysis_relative_humidity_percent  \
# 0                            32.00                             73.365714
# ...

# %%
b_sj.shape
# Out:
# (936, 24)

# %%
b_iq.head()
# Out:
#     week_start_date city  year  weekofyear   ndvi_ne   ndvi_nw   ndvi_se  \
# 936      2000-07-01   iq  2000          26  0.192886  0.132257  0.340886
# 937      2000-07-08   iq  2000          27  0.216833  0.276100  0.289457
# 938      2000-07-15   iq  2000          28  0.176757  0.173129  0.204114
# 939      2000-07-22   iq  2000          29  0.227729  0.145429  0.254200
# 940      2000-07-29   iq  2000          30  0.328643  0.322129  0.254371
#
#       ndvi_sw  precipitation_amt_mm  reanalysis_air_temp_k  ...  \
# 936  0.247200                 25.41             296.740000  ...
# 937  0.241657                 60.61             296.634286  ...
# 938  0.128014                 55.52             296.415714  ...
# 939  0.200314                  5.60             295.357143  ...
# 940  0.361043                 62.76             296.432857  ...
#
#      reanalysis_precip_amt_kg_per_m2  reanalysis_relative_humidity_percent  \
# ...

# %%
b_iq.shape
# Out:
# (520, 24)

# %%
# making sepertae training label 
b_sj_labels = labels.copy()
b_iq_labels = labels.copy()

# %%
b_sj_labels.drop(b_sj_labels[b_sj_labels['city'] != 'sj'].index,inplace = True)
b_iq_labels.drop(b_iq_labels[b_iq_labels['city'] != 'iq'].index,inplace = True)

# %%
b_sj_labels.head()
# Out:
#   city  year  weekofyear  total_cases
# 0   sj  1990          18            4
# 1   sj  1990          19            5
# 2   sj  1990          20            4
# 3   sj  1990          21            3
# 4   sj  1990          22            6

# %%
b_sj_labels = b_sj_labels.drop('city', axis = 1)
b_iq_labels = b_iq_labels.drop('city', axis = 1)

# %%
b_sj_labels.head()
#b_iq_labels.head()
# Out:
#    year  weekofyear  total_cases
# 0  1990          18            4
# 1  1990          19            5
# 2  1990          20            4
# 3  1990          21            3
# 4  1990          22            6

# %%
b_sj_labels.shape
# Out:
# (936, 3)

# %%
b_iq_labels.shape
# Out:
# (520, 3)

# %%
labels['total_cases'].hist(bins=20)

# %%
# split the training lables
sj_cases = labels[labels['city'] == 'sj']
iq_cases = labels[labels['city'] == 'iq']

# %%
# cases in San Juan
sj_cases['total_cases'].plot()

# %%
# cases in Iquitos
iq_cases['total_cases'].plot()
